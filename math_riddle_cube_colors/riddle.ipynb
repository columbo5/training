# %%
from riddle import Cube, CubeGrid

# %%
testgrid = CubeGrid.generate_random(seed=10)

# %%
testgrid.count_colors()
# Out:
# Counter({'g': 27, 'r': 20, 'b': 17})

# %%
testgrid.count_squared_distances(color="b")
# Out:
# Counter({10: 17,
#          5: 17,
#          14: 14,
#          2: 12,
#          6: 11,
#          8: 10,
#          9: 10,
#          11: 9,
#          13: 7,
#          3: 7,
#          4: 6,
#          1: 5,
#          17: 4,
#          22: 2,
#          18: 2,
#          12: 2,
#          19: 1})

# %%
testgrid.has_minimum_six_equal_color_equal_dist_pairs()
# Out:
# True

# %%
testiter = iter(testgrid)
print(next(testiter))
# Out:
# Cube(coordinate=(0, 0, 0), color='b')
